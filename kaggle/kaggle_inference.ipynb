# %% [markdown]
# # Training & Inference

# %% [markdown]
# ## Getting Environment Variables

# %%
import os
import sys
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
github_token=user_secrets.get_secret("GITHUB_TOKEN")
os.environ["WANDB_API_KEY"]=user_secrets.get_secret("WANDB_API_KEY")
os.environ["KAGGLE_USERNAME"]=user_secrets.get_secret("KAGGLE_USERNAME")
os.environ["KAGGLE_API_TOKEN"]=user_secrets.get_secret("KAGGLE_API_TOKEN")
os.environ["HF_TOKEN"]=user_secrets.get_secret("HF_TOKEN")

# %% [markdown]
# ## Clone Github Repo

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
# !git clone --depth 1 https://dhruvbansalup:{github_token}@github.com/dhruvbansalup/dl-genai-project-26-t2-Smart_MCQ_Solver.git
# %cd /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
# !pip install -qq -r requirements.txt
# !pip install -qq faiss-cpu==1.14.3
# Out:
# /kaggle/working
# Cloning into 'dl-genai-project-26-t2-Smart_MCQ_Solver'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 76 (delta 8), reused 34 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (76/76), 955.23 KiB | 6.73 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 7.1 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement pywin32==311 (from versions: none)
# ERROR: No matching distribution found for pywin32==311
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 65.2 MB/s eta 0:00:00

# %% [markdown]
# ## Training

# %%
# # Training TFIDF-LGBM
# !python -m src.training.train_classical_tfidf_lgbm --log True --uploadToKaggle True

# # Training BiLSTM
# !python -m src.training.train_bilstm --log False --uploadToKaggle False

# # Training BERT
# !python -m src.training.train_transformer --model BERT --log True --uploadToKaggle True

# # Training RoBERTa
# !python -m src.training.train_transformer --model RoBERTa --log True --uploadToKaggle True

# # Training DeBERTa_v3_base
# !python -m src.training.train_transformer --model DeBERTa_v3_base --log True --uploadToKaggle True

# # Training BERT with RAG
# !python -m src.training.train_transformer_with_rag --model BERT --log True --uploadToKaggle True

# # Training RoBERTa with RAG
# !python -m src.training.train_transformer_with_rag --model RoBERTa --log True --uploadToKaggle True

# # Training DeBERTa_v3_base with RAG
# !python -m src.training.train_transformer_with_rag --model DeBERTa_v3_base --log True --uploadToKaggle True --batch_size 2

# # Training BERT with processed_data_v002
# !python -m src.training.train_transformer_data_v002 --model BERT --log True --uploadToKaggle True

# Training RoBERTa with processed_data_v002
# !python -m src.training.train_transformer_data_v002 --model RoBERTa --log True --uploadToKaggle True

# Training DeBERTa_v3_base with processed_data_v002
# !python -m src.training.train_transformer_data_v002 --model DeBERTa_v3_base --log True --uploadToKaggle True
# Out:
# Processed data not found. Creating processed data...
# modules.json: 100%|████████████████████████████| 349/349 [00:00<00:00, 1.47MB/s]
# config_sentence_transformers.json: 100%|████████| 116/116 [00:00<00:00, 469kB/s]
# README.md: 10.5kB [00:00, 3.35MB/s]
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 230kB/s]
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 2.45MB/s]
# model.safetensors: 100%|███████████████████| 90.9M/90.9M [00:01<00:00, 62.9MB/s]
# Loading weights: 100%|█| 103/103 [00:00<00:00, 1211.37it/s, Materializing param=
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json: 100%|███████████████████| 350/350 [00:00<00:00, 1.48MB/s]
# vocab.txt: 232kB [00:00, 13.2MB/s]
# tokenizer.json: 466kB [00:00, 13.8MB/s]
# special_tokens_map.json: 100%|██████████████████| 112/112 [00:00<00:00, 378kB/s]
# config.json: 100%|██████████████████████████████| 190/190 [00:00<00:00, 546kB/s]
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Found GPU0 Tesla P100-PCIE-16GB which is of cuda capability 6.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
# Tesla P100-PCIE-16GB with CUDA capability sm_60 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_70 sm_75 sm_80 sm_86 sm_90 sm_100 sm_120.
# If you want to use the Tesla P100-PCIE-16GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   queued_call()
# Batches:   0%|                                           | 0/57 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/src/training/train_transformer_data_v002.py", line 63, in <module>
#     train_transformer(model_class=model_class, tokenizer_model_name=tokenizer_model_name, log=args.log, uploadToKaggle=args.uploadToKaggle)
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/src/training/train_transformer_data_v002.py", line 14, in train_transformer
#     ensure_processed_data_exists_v002()
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/scripts/make_processed_data_v002.py", line 108, in ensure_processed_data_exists_v002
#     create_processed_data_v002()
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/scripts/make_processed_data_v002.py", line 94, in create_processed_data_v002
#     train_df, val_df = split_train_validation(df)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/scripts/make_processed_data_v002.py", line 17, in split_train_validation
#     embeddings = model.encode(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/util/decorators.py", line 41, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/sentence_transformer/model.py", line 651, in encode
#     out_features = self.forward(features, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/base/model.py", line 486, in forward
#     input = module(input, **module_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/base/modules/transformer.py", line 1046, in forward
#     model_output = model_method(**filtered_kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py", line 1002, in wrapper
#     outputs = func(self, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py", line 677, in forward
#     cache_position = torch.arange(past_key_values_length, past_key_values_length + seq_length, device=device)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: no kernel image is available for execution on the device
# Search for `cudaErrorNoKernelImageForDevice' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Processed data not found. Creating processed data...
# Loading weights: 100%|█| 103/103 [00:00<00:00, 1468.83it/s, Materializing param=
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Found GPU0 Tesla P100-PCIE-16GB which is of cuda capability 6.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
# Tesla P100-PCIE-16GB with CUDA capability sm_60 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_70 sm_75 sm_80 sm_86 sm_90 sm_100 sm_120.
# If you want to use the Tesla P100-PCIE-16GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   queued_call()
# Batches:   0%|                                           | 0/57 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/src/training/train_transformer_data_v002.py", line 63, in <module>
#     train_transformer(model_class=model_class, tokenizer_model_name=tokenizer_model_name, log=args.log, uploadToKaggle=args.uploadToKaggle)
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/src/training/train_transformer_data_v002.py", line 14, in train_transformer
#     ensure_processed_data_exists_v002()
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/scripts/make_processed_data_v002.py", line 108, in ensure_processed_data_exists_v002
#     create_processed_data_v002()
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/scripts/make_processed_data_v002.py", line 94, in create_processed_data_v002
#     train_df, val_df = split_train_validation(df)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver/scripts/make_processed_data_v002.py", line 17, in split_train_validation
#     embeddings = model.encode(
#                  ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/util/decorators.py", line 41, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/sentence_transformer/model.py", line 651, in encode
#     out_features = self.forward(features, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/base/model.py", line 486, in forward
#     input = module(input, **module_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sentence_transformers/base/modules/transformer.py", line 1046, in forward
#     model_output = model_method(**filtered_kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py", line 1002, in wrapper
#     outputs = func(self, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/bert/modeling_bert.py", line 677, in forward
#     cache_position = torch.arange(past_key_values_length, past_key_values_length + seq_length, device=device)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: no kernel image is available for execution on the device
# Search for `cudaErrorNoKernelImageForDevice' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# ## Inference

# %%
# # Infer TFIDF-LGBM
# !python -m src.inference.infer_classical_tfidf_lgbm

# # Infer BiLSTM01
# !python -m src.inference.infer_bilstm

# # Infer Zero-Shot bart-large-mnli
# !python -m src.inference.infer_zero_shot_bart_large_mnli

# # Infer BERT
# !python -m src.inference.infer_transformer --model BERT 

# # Infer RoBERTa
# !python -m src.inference.infer_transformer --model RoBERTa

# # Infer DeBERTa_v3_base
# !python -m src.inference.infer_transformer --model DeBERTa_v3_base

# # Infer Ensemble - BERT+RoBERTa+DeBERTa
# !python -m src.inference.infer_ensemble

# # Infer BERT_RAG
# !python -m src.inference.infer_transformer_with_rag --model BERT_RAG

# # Infer RoBERTa_RAG
# !python -m src.inference.infer_transformer_with_rag --model RoBERTa_RAG

# # Infer DeBERTa_v3_base_RAG
# !python -m src.inference.infer_transformer_with_rag --model DeBERTa_v3_base_RAG
