# %% [markdown]
# # Setup

# %% [markdown]
# ## Getting Environment Variables

# %%
import os
import sys
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
github_token=user_secrets.get_secret("GITHUB_TOKEN")
os.environ["WANDB_API_KEY"]=user_secrets.get_secret("WANDB_API_KEY")
os.environ["KAGGLE_USERNAME"]=user_secrets.get_secret("KAGGLE_USERNAME")
os.environ["KAGGLE_API_TOKEN"]=user_secrets.get_secret("KAGGLE_API_TOKEN")

# %% [markdown]
# ## Clone Github Repo

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
# !git clone --depth 1 https://dhruvbansalup:{github_token}@github.com/dhruvbansalup/dl-genai-project-26-t2-Smart_MCQ_Solver.git
# %cd /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
# Out:
# /kaggle/working
# Cloning into 'dl-genai-project-26-t2-Smart_MCQ_Solver'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 48 (delta 0), reused 28 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 912.95 KiB | 1.58 MiB/s, done.
# /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver

# %% [markdown]
# # Training

# %% [markdown]
# ## Training TFIDF-LGBM

# %%
# # Generating Processed Data
# !python -m scripts.make_processed_data_v001
# # Training baseline tfidf_lgbm
# !python -m src.models.classical.tfidf_lgbm

# %% [markdown]
# ## Training BiLSTM01

# %%
# !python -m src.training.train_bilstm --log False --uploadToKaggle False

# %% [markdown]
# # Inference

# %%
# !python -m src.inference.infer_bilstm
# Out:
# Downloading model from KaggleHub: dhruvbansalup/dl-genai-project-26-t2-smart-mcq-solver/pyTorch/bilstm01
# Mounting files to /kaggle/input/models/dhruvbansalup/dl-genai-project-26-t2-smart-mcq-solver/pytorch/bilstm01/1...
# Model downloaded to: /kaggle/input/models/dhruvbansalup/dl-genai-project-26-t2-smart-mcq-solver/pytorch/bilstm01/1/BiLSTM01-epoch05-val_map30.9767-v1.ckpt
# Model Loaded Successfully!
# Processed data not found. Creating processed data...
# Processed data created successfully.
# Generating Predictions:   0%|                            | 0/16 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Generating Predictions: 100%|███████████████████| 16/16 [00:27<00:00,  1.71s/it]
# Predictions Generated Successfully!
# Submission file created at: /kaggle/working/submission.csv
