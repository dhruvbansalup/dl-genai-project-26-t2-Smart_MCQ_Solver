# %% [markdown]
# # Setup

# %% [markdown]
# ## Getting Environment Variables

# %%
import os
import sys
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
github_token=user_secrets.get_secret("GITHUB_TOKEN")
os.environ["WANDB_API_KEY"]=user_secrets.get_secret("WANDB_API_KEY")
os.environ["KAGGLE_USERNAME"]=user_secrets.get_secret("KAGGLE_USERNAME")
os.environ["KAGGLE_API_TOKEN"]=user_secrets.get_secret("KAGGLE_API_TOKEN")
os.environ["HF_TOKEN"]=user_secrets.get_secret("HF_TOKEN")

# %% [markdown]
# ## Clone Github Repo

# %%
# %cd /kaggle/working/
# !rm -rf /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
# !git clone --depth 1 https://dhruvbansalup:{github_token}@github.com/dhruvbansalup/dl-genai-project-26-t2-Smart_MCQ_Solver.git
# %cd /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver
# Out:
# /kaggle/working
# Cloning into 'dl-genai-project-26-t2-Smart_MCQ_Solver'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 60 (delta 3), reused 29 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 956.56 KiB | 8.94 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /kaggle/working/dl-genai-project-26-t2-Smart_MCQ_Solver

# %% [markdown]
# # Training

# %% [markdown]
# ## Training TFIDF-LGBM

# %%
# # Generating Processed Data
# !python -m scripts.make_processed_data_v001
# # Training baseline tfidf_lgbm
# !python -m src.models.classical.tfidf_lgbm

# %% [markdown]
# ## Training BiLSTM01

# %%
# !python -m src.training.train_bilstm --log False --uploadToKaggle False

# %% [markdown]
# ## Training Transformers

# %%
# # BERT
# !python -m src.training.train_transformer --model BERT --log True --uploadToKaggle True

# RoBERTa
# !python -m src.training.train_transformer --model RoBERTa --log True --uploadToKaggle True
# Out:
# Processed data not found. Creating processed data...
# Processed data created successfully.
# config.json: 100%|█████████████████████████████| 481/481 [00:00<00:00, 2.92MB/s]
# tokenizer_config.json: 100%|██████████████████| 25.0/25.0 [00:00<00:00, 209kB/s]
# vocab.json: 899kB [00:00, 22.2MB/s]
# merges.txt: 456kB [00:00, 36.2MB/s]
# tokenizer.json: 1.36MB [00:00, 29.7MB/s]
# model.safetensors: 100%|██████████████████████| 499M/499M [00:02<00:00, 189MB/s]
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1547.91it/s, Materializing param=
# RobertaModel LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Seed set to 42
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Starting training for RoBERTa...
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# Processed data already exists.
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1604.59it/s, Materializing param=
# RobertaModel LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# pooler.dense.weight             | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [rank: 1] Seed set to 42
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Starting training for RoBERTa...
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run RoBERTa-2026-07-03_03-15-55-7fb6 (0.2s)
# wandb: ⣾ setting up run RoBERTa-2026-07-03_03-15-55-7fb6 (0.2s)
# wandb: ⣷ setting up run RoBERTa-2026-07-03_03-15-55-7fb6 (0.2s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /kaggle/working/outputs/wandb/run-20260702_214608-RoBERTa-2026-07-03_03-15-55-7fb6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RoBERTa-2026-07-03 03:15:55
# wandb: ⭐️ View project at https://wandb.ai/24f1001707-dl-genai-project/24f1001707-t22026
# wandb: 🚀 View run at https://wandb.ai/24f1001707-dl-genai-project/24f1001707-t22026/runs/RoBERTa-2026-07-03_03-15-55-7fb6
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ val_accuracy  │ MulticlassAccuracy │      0 │ train │     0 │
# │ 1 │ val_accuracy3 │ MulticlassAccuracy │      0 │ train │     0 │
# │ 2 │ encoder       │ RobertaModel       │  124 M │ train │     0 │
# │ 3 │ classifier    │ Sequential         │  591 K │ train │     0 │
# └───┴───────────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 125 M
# Non-trainable params: 0
# Total params: 125 M
# Total estimated model params size (MB): 500.948
# Modules in train mode: 236
# Modules in eval mode: 0
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:2
# 1: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec,
# TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/log
# ger_connector/result.py:433: It is recommended to use `self.log('val_loss', ...,
# sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/log
# ger_connector/result.py:433: It is recommended to use `self.log('val_accuracy',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/log
# ger_connector/result.py:433: It is recommended to use `self.log('val_accuracy3',
# ..., sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/log
# ger_connector/result.py:433: It is recommended to use `self.log('val_map3', ...,
# sync_dist=True)` when logging on epoch level in distributed setting to
# accumulate the metric across devices.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/log
# ger_connector/result.py:433: It is recommended to use
# `self.log('val_epoch_duration', ..., sync_dist=True)` when logging on epoch
# level in distributed setting to accumulate the metric across devices.
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 0/113 0:00:00 • -:--:-- 0.00it/s v_num: 7fb6
#                                                               val_loss: 1.610
#                                                               val_accuracy:
#                                                               0.058
#                                                               val_accuracy3:
#                                                               0.375 val_map3:
#                                                               0.167             /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865:
# UserWarning: The AccumulateGrad node's stream does not match the stream of the
# node that produced the incoming gradient. This may incur unnecessary
# synchronization and break CUDA graph capture if the AccumulateGrad node's stream
# is the default stream. This mismatch is caused by an AccumulateGrad node created
# prior to the current iteration being kept alive. This can happen if the autograd
# graph is still being kept alive by tensors such as the loss, or if you are using
# DDP, which will stash a reference to the node. To resolve the mismatch, delete
# all references to the autograd graph or ensure that DDP initialization is
# performed under the same stream as subsequent forwards. If the mismatch is
# intentional, you can use
# torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to
# suppress this warning. (Triggered internally at
# /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine
# to run the backward pass
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 0/113 0:00:00 • -:--:-- 0.00it/s v_num: 7fb6
#                                                               val_loss: 1.610
#                                                               val_accuracy:
#                                                               0.058
#                                                               val_accuracy3:
#                                                               0.375 val_map3:
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 1/113 0:00:00 • -:--:-- 0.00it/s v_num: 7fb6
#                                                               val_loss: 1.610
#                                                               val_accuracy:
#                                                               0.058
#                                                               val_accuracy3:
#                                                               0.375 val_map3:
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 1/113 0:00:00 • -:--:-- 0.00it/s v_num: 7fb6
#                                                               train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 2/113 0:00:01 • 0:00:45 2.48it/s v_num: 7fb6
#                                                               train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 2/113 0:00:01 • 0:00:45 2.48it/s v_num: 7fb6
#                                                               train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━━━━━ 3/113 0:00:01 • 0:00:46 2.42it/s v_num: 7fb6
#                                                               train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━
/s v_num: 7fb6
#                                                                train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:48 • 0:00:00 2.33it/s v_num: 7fb6
#                                                                train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:48 • 0:00:00 2.33it/s v_num: 7fb6
#                                                                train_loss_step:
# Epoch 0/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:48 • 0:00:00 2.33it/s v_num: 7fb6
# ...
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.054
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.010
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.003
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.037            `Trainer.fit` stopped: `max_epochs=6` reached.
# Training completed for RoBERTa.
# Epoch 5/5  ━━━━━━━━━━━━━━━━ 113/113 0:00:51 • 0:00:00 2.19it/s v_num: 7fb6
#                                                                train_loss_step:
#                                                                0.001 val_loss:
#                                                                0.003
#                                                                val_accuracy:
#                                                                1.000
#                                                                val_accuracy3:
#                                                                1.000 val_map3:
#                                                                1.000
#                                                                train_loss_epoch:
#                                                                0.037
# Uploading Model https://api.kaggle.com/models/dhruvbansalup/dl-genai-project-26-t2-smart-mcq-solver/pytorch/roberta ...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 1.0.0), please consider upgrading to the latest version (1.0.2)Error uploading model to Kagglehub: Please upload at least one file
# Training completed for RoBERTa.
# Uploading Model https://api.kaggle.com/models/dhruvbansalup/dl-genai-project-26-t2-smart-mcq-solver/pytorch/roberta ...
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 1.0.0), please consider upgrading to the latest version (1.0.2)Starting upload for file /kaggle/working/outputs/checkpoints/RoBERTa-epoch=03-val_map3=1.0000.ckpt
# Uploading: 100%|███████████████████████████| 1.50G/1.50G [00:15<00:00, 97.4MB/s]
# Upload successful: /kaggle/working/outputs/checkpoints/RoBERTa-epoch=03-val_map3=1.0000.ckpt (1GB)
# Your model instance has been created.
# Files are being processed...
# See at: https://api.kaggle.com/models/dhruvbansalup/dl-genai-project-26-t2-smart-mcq-solver/pytorch/roberta
# roberta Model uploaded to Kagglehub Successfully!
# wandb: ⢿ uploading artifact model-RoBERTa-2026-07-03_03-15-55-7fb6 (18s)
# wandb: ⢿ updating run metadata (0.0s)
# wandb: ⣻ uploading artifact model-RoBERTa-2026-07-03_03-15-55-7fb6 (18s)
# wandb: ⣻ updating run metadata (0.0s)
# wandb: ⣽ uploading artifact model-RoBERTa-2026-07-03_03-15-55-7fb6 (18s)
# wandb: ⣽ updating run metadata (0.0s)
# wandb: ⣾ uploading artifact model-RoBERTa-2026-07-03_03-15-55-7fb6 (18s)
# wandb: ⣾ updating run metadata (0.0s)
# wandb: ⣷ uploading output.log 1.3MB/1.3MB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 392B/392B (0.1s)
# wandb: ⣷ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb: ⣯ uploading output.log 1.3MB/1.3MB (0.1s)
# wandb: ⣯ uploading wandb-summary.json 392B/392B (0.1s)
# wandb: ⣯ uploading config.yaml 2.8KB/2.8KB (0.1s)
# wandb:
# wandb: Run history:
# wandb:                epoch ▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▄▄▄▄▄▄▄▄▄▅▅▅▅▇▇▇▇▇▇█████
# wandb:                   lr ▁▁▁▁▁▁
# wandb: train_epoch_duration ▁▆███▇
# wandb:     train_loss_epoch █▅▂▁▁▁
# wandb:      train_loss_step █████▆▆▆▄▅▂▃▃▄▃▁▃▂▁▁▂▁▁▁▁▁▂▁▁▁▁▂▁▁▂▁▁▁▁▁
# wandb:  trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████
# wandb:         val_accuracy ▁▆████
# wandb:        val_accuracy3 ▁▆▇███
# wandb:   val_epoch_duration ▁▃▆▇▆█
# wandb:             val_loss █▃▁▁▁▁
# wandb:                   +1 ...
# wandb:
# wandb: Run summary:
# wandb:                epoch 5
# wandb:                   lr 2e-05
# wandb: train_epoch_duration 53.62235
# wandb:     train_loss_epoch 0.0365
# wandb:      train_loss_step 0.00247
# wandb:  trainer/global_step 677
# wandb:         val_accuracy 1
# wandb:        val_accuracy3 1
# wandb:   val_epoch_duration 1.60605
# wandb:             val_loss 0.00276
# wandb:                   +1 ...
# wandb:
# wandb: 🚀 View run RoBERTa-2026-07-03 03:15:55 at: https://wandb.ai/24f1001707-dl-genai-project/24f1001707-t22026/runs/RoBERTa-2026-07-03_03-15-55-7fb6
# wandb: ⭐️ View project at: https://wandb.ai/24f1001707-dl-genai-project/24f1001707-t22026
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /kaggle/working/outputs/wandb/run-20260702_214608-RoBERTa-2026-07-03_03-15-55-7fb6/logs

# %% [markdown]
# # Inference

# %%
# # Infer BiLSTM01
# !python -m src.inference.infer_bilstm

# # Infer Zero-Shot bart-large-mnli
# !python -m src.inference.infer_zero_shot_bart_large_mnli

# # Infer BERT
# !python -m src.inference.infer_transformer --model BERT
